# %%
import pandas as pd
import numpy as np
import boto3
import io
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

bucket_name = 'ssa-oc-bucket'

# %%
# read sales data
s3 = boto3.client('s3', aws_access_key_id= 'AKIAVNWCBZPGPW4OB7H7',
                    aws_secret_access_key='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')
object_key = 'source/OC_Historic_Sales_Data/Condensed_Glass_Reinforcements_2014-2021_Sales_Data.xlsx'
obj = s3.get_object(Bucket=bucket_name, Key=object_key)
data = obj['Body'].read()
gr_revenue = pd.read_excel(io.BytesIO(data),engine='openpyxl')
gr_revenue = gr_revenue[gr_revenue['External/Downstream']=='External']
gr_revenue = gr_revenue[gr_revenue['End Use Market']!= '10K REVENUE PLUG']
gr_revenue = gr_revenue[gr_revenue['End Use Market']!= 'BPC DATA PLUG']
gr_revenue = gr_revenue[gr_revenue['End Use Market']!= 'BPC  REVENUE PLUG']
gr_revenue = gr_revenue[gr_revenue['Region']!= 'Not assigned']
gr_revenue = gr_revenue[gr_revenue['End Use Market (Sub)']!= 'NOT ASSIGNED']
gr_revenue = gr_revenue[gr_revenue['End Use Market (Sub)']!= 'Not Assigned']
gr_revenue = gr_revenue[gr_revenue['End Use Market']!= 'Not Assigned']
gr_revenue = gr_revenue[gr_revenue['Product']!= 'DUCS']

# %%
BL_Non_Residential = gr_revenue[gr_revenue['End Use Market (Sub)']=='BL-NONRESIDENTIAL']
BL_Non_Residential_month = BL_Non_Residential.groupby(['Country','Year','Month'])['Sales'].agg(sum).reset_index()

# %%
US_BL_Non_Residential_month = BL_Non_Residential_month[BL_Non_Residential_month['Country']=='USA']

# %%
US_BL_Non_Residential_month
# Out:
#      Country  Year  Month       Sales
# 2038     USA  2014      1 2706936.440
# 2039     USA  2014      2 2994153.050
# 2040     USA  2014      3 2946764.240
# 2041     USA  2014      4 2611462.490
# 2042     USA  2014      5 2908492.550
# 2043     USA  2014      6 2941824.090
# 2044     USA  2014      7 3053183.080
# 2045     USA  2014      8 2798889.990
# 2046     USA  2014      9 3414404.510
# 2047     USA  2014     10 2138737.500
# 2048     USA  2014     11 1729662.730
# 2049     USA  2014     12 1766980.670
# 2050     USA  2015      1 2221994.830
# 2051     USA  2015      2 1824463.150
# 2052     USA  2015      3 2344780.880
# 2053     USA  2015      4 2308184.390
# 2054     USA  2015      5 1841645.190
# 2055     USA  2015      6 2053057.690
# 2056     USA  2015      7 2015482.910
# 2057     USA  2015      8 2081287.320
# 2058     USA  2015      9 2002791.460
# 2059     USA  2015     10 2766115.840
# 2060     USA  2015     11 1863239.320
# 2061     USA  2015     12 1853354.120
# ...

# %% [markdown]
# # Construction

# %%
s3 = boto3.client('s3', aws_access_key_id= 'AKIAVNWCBZPGPW4OB7H7',
                    aws_secret_access_key='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')
object_key = 'source/End_Market_Data/US_Construction_Monthly.xlsx'
obj = s3.get_object(Bucket=bucket_name, Key=object_key)
data = obj['Body'].read()
US_Nonres = pd.read_excel(io.BytesIO(data),engine='openpyxl',sheet_name='US_Non-Res')

# %%
US_Nonres.head()
# Out:
#   Month/Year  Non-Residential (Commercial Buildings, SAAR)  \
# 0 2002-01-01                                         68254
# 1 2002-02-01                                         65840
# 2 2002-03-01                                         66722
# 3 2002-04-01                                         64879
# 4 2002-05-01                                         62741
#
#    Non-Residential (Commercial Buildings, NSA)
# 0                                         4887
# 1                                         4825
# 2                                         5102
# 3                                         5267
# 4                                         5220

# %%
def get_year_month1(df):
    df['Year'] = df['Month/Year'].dt.year
    df['Month'] = df['Month/Year'].dt.month
    return df

# %%
US_Nonres = get_year_month1(US_Nonres)
US_Nonres = US_Nonres[['Year','Month','Non-Residential (Commercial Buildings, SAAR)',
                       'Non-Residential (Commercial Buildings, NSA)']]

# %%
US_BL_Non_Residential_df = US_BL_Non_Residential_month.merge(US_Nonres, on=['Year','Month'], how='left')

# %%
US_BL_Non_Residential_df.head()
# Out:
#   Country  Year  Month       Sales  \
# 0     USA  2014      1 2706936.440
# 1     USA  2014      2 2994153.050
# 2     USA  2014      3 2946764.240
# 3     USA  2014      4 2611462.490
# 4     USA  2014      5 2908492.550
#
#    Non-Residential (Commercial Buildings, SAAR)  \
# 0                                         54751
# 1                                         57360
# 2                                         58172
# 3                                         58365
# 4                                         60482
#
#    Non-Residential (Commercial Buildings, NSA)
# 0                                         3894
# 1                                         4155
# 2                                         4492
# 3                                         4857
# 4                                         5148

# %% [markdown]
# # Housing Starts

# %%
s3 = boto3.client('s3', aws_access_key_id= 'AKIAVNWCBZPGPW4OB7H7',
                    aws_secret_access_key='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')
object_key = 'source/End_Market_Data/US_Housing_Starts_1960-2021_Monthly_Consolidated.xlsx'
obj = s3.get_object(Bucket=bucket_name, Key=object_key)
data = obj['Body'].read()
US_housing = pd.read_excel(io.BytesIO(data),engine='openpyxl',sheet_name='Consolidated_StartsSA')

# %%
US_BL_Non_Residential_df1 = US_BL_Non_Residential_df.merge(US_housing, on=['Year','Month'], how='left')

# %%
US_BL_Non_Residential_df1.head()
# Out:
#   Country  Year  Month       Sales  \
# 0     USA  2014      1 2706936.440
# 1     USA  2014      2 2994153.050
# 2     USA  2014      3 2946764.240
# 3     USA  2014      4 2611462.490
# 4     USA  2014      5 2908492.550
#
#    Non-Residential (Commercial Buildings, SAAR)  \
# 0                                         54751
# 1                                         57360
# 2                                         58172
# 3                                         58365
# 4                                         60482
#
#    Non-Residential (Commercial Buildings, NSA)  Total  1_unit  \
# 0                                         3894    888     567
# 1                                         4155    944     594
# 2                                         4492    970     652
# 3                                         4857   1043     646
# 4                                         5148   1007     652
#
#    5_or_more_units  Northeast_total  Northeast_1_unit  Midwest_total  \
# ...

# %% [markdown]
# # Composites Industry data

# %%
# s3 = boto3.client('s3', aws_access_key_id= 'AKIAVNWCBZPGPW4OB7H7',
#                     aws_secret_access_key='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')
# object_key = 'source/NA&EU_Fiberglass_Trade_Association_Files/Composites_Industry_Data_2019-2021_ACMA_04-2021_Monthly.xlsx'
# obj = s3.get_object(Bucket=bucket_name, Key=object_key)
# data = obj['Body'].read()
# composites_industry = pd.read_excel(io.BytesIO(data),engine='openpyxl',sheet_name='Datastack')

# %%
# composites_industry_non_res = composites_industry[(composites_industry['Market Segment']=='Construction')&
#                              (composites_industry['Submarket']=='Architectural & Structural')].reset_index(drop=True)

# %%
# composites_industry_non_res = composites_industry_non_res[['Year','Month','Value']]
# composites_industry_non_res = composites_industry_non_res.rename(columns={'Value':'composites_industry_value'})

# %%
# US_BL_Non_Residential_df2 = US_BL_Non_Residential_df1.merge(composites_industry_non_res, on=['Year','Month'], how='left')

# %% [markdown]
# # Market Data

# %%
s3 = boto3.client('s3', aws_access_key_id= 'AKIAVNWCBZPGPW4OB7H7',
                    aws_secret_access_key='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')
object_key = 'source/NA&EU_Fiberglass_Trade_Association_Files/EU(APFE)_and_NA(ACMA)_Market_Data_2011-2021_Monthly.xlsx'
obj = s3.get_object(Bucket=bucket_name, Key=object_key)
data = obj['Body'].read()
market = pd.read_excel(io.BytesIO(data),engine='openpyxl', sheet_name='US Market History')

# %%
market['Year'] = market['DATE'].dt.year
market['Month'] = market['DATE'].dt.month

# %%
market = market[['Year','Month','SE Rovings','ME Rovings','CSM','CFM','WUCS']]

# %%
US_BL_Non_Residential_df2 = US_BL_Non_Residential_df1.merge(market, on=['Year','Month'], how='left')

# %%
US_BL_Non_Residential_df2
# Out:
#    Country  Year  Month       Sales  \
# 0      USA  2014      1 2706936.440
# 1      USA  2014      2 2994153.050
# 2      USA  2014      3 2946764.240
# 3      USA  2014      4 2611462.490
# 4      USA  2014      5 2908492.550
# 5      USA  2014      6 2941824.090
# 6      USA  2014      7 3053183.080
# 7      USA  2014      8 2798889.990
# 8      USA  2014      9 3414404.510
# 9      USA  2014     10 2138737.500
# 10     USA  2014     11 1729662.730
# 11     USA  2014     12 1766980.670
# 12     USA  2015      1 2221994.830
# 13     USA  2015      2 1824463.150
# 14     USA  2015      3 2344780.880
# 15     USA  2015      4 2308184.390
# 16     USA  2015      5 1841645.190
# 17     USA  2015      6 2053057.690
# 18     USA  2015      7 2015482.910
# 19     USA  2015      8 2081287.320
# 20     USA  2015      9 2002791.460
# 21     USA  2015     10 2766115.840
# 22     USA  2015     11 1863239.320
# 23     USA  2015     12 1853354.120
# 24     USA  2016      1 2052508.190
# ...

# %%
US_BL_Non_Residential_df2.to_csv('BL_Non_Residential_US_Monthly.csv', index=False)
